# %% [markdown]
# <a href="https://colab.research.google.com/github/rdestro/ColabPythonJourneyFiap/blob/main/PRF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Carregando as bibliotecas
import pandas as pd
from pandas import read_csv
from pandas.plotting import scatter_matrix
from matplotlib import pyplot

# %%
# Carregando o Dataeet
url = "/content/datatran2020.csv"

datatran2020 = read_csv(url,delimiter=';',encoding='latin-1',error_bad_lines=False,engine='python')

datatran2020
# Out:
#              id data_inversa    dia_semana  ... regional delegacia       uop
# 0      260031.0   2020-01-01  quarta-feira  ...    SR-TO  UOP01/TO       NaN
# 1      260036.0   2020-01-01  quarta-feira  ...    SR-RJ    DEL5/1  UOP02/RJ
# 2      260037.0   2020-01-01  quarta-feira  ...    SR-SC    DEL8/1  UOP01/SC
# 3      260038.0   2020-01-01  quarta-feira  ...    SR-RO   DEL21/2  UOP02/RO
# 4      260039.0   2020-01-01  quarta-feira  ...    SR-PR    DEL7/3  UOP04/PR
# ...         ...          ...           ...  ...      ...       ...       ...
# 63543  364615.0   2020-03-20   sexta-feira  ...    SR-RN     UOP03     DEL01
# 63544  364810.0   2020-09-12        sábado  ...    SR-BA     UOP01     DEL08
# 63545  364817.0   2020-10-30   sexta-feira  ...    SR-BA     UOP01     DEL08
# 63546  364835.0   2020-09-20       domingo  ...    SR-BA     UOP01     DEL08
# 63547  364903.0   2020-10-31        sábado  ...    SR-BA     UOP01     DEL08
#
# [63548 rows x 30 columns]

# %%
# Conhecendo o Dataeet
print("Descrição do Dataset"+"\n")
print(datatran2020.describe())


print("\n\n\n"+"Categorias\n")
print(datatran2020.groupby('uf').size())
# Out:
# Descrição do Dataset
#
#                   id            br  ...       feridos      veiculos
# count   63548.000000  63390.000000  ...  63548.000000  63548.000000
# mean   296567.776972    212.437482  ...      1.124819      1.634151
# std     21063.404634    131.036675  ...      1.113988      0.724907
# min    260031.000000     10.000000  ...      0.000000      1.000000
# 25%    278493.750000    101.000000  ...      1.000000      1.000000
# 50%    296586.500000    163.000000  ...      1.000000      2.000000
# 75%    314604.250000    324.000000  ...      1.000000      2.000000
# max    364903.000000    495.000000  ...     44.000000     23.000000
#
# [8 rows x 10 columns]
#
#
#
# Categorias
#
# uf
# AC     300
# AL     628
# AM     138
# AP     155
# BA    3456
# CE    1571
# DF    1040
# ES    2534
# GO    3228
# MA    1154
# MG    8374
# MS    1540
# MT    2195
# PA     963
# PB    1401
# PE    2560
# PI    1203
# PR    7190
# RJ    4236
# RN    1337
# RO    1486
# RR     250
# ...
